# %% [markdown]
# # P13-1 실습 과제
# ##Mini-batch size & Learning Rate 튜닝

# %%
# mlp for the blobs problem with minibatch gradient descent with varied batch size
# 아래의 코드에서 다음 두 개의 파라미터를 조합하여 최고의 모델링 성능을 내고 그 결과를 print()로 출력하십시오.
# 튜닝할 파라미터 : batch_size & lr (각각 3가지의 옵션이 있으므로 두 파라미터를 조합할 수 있는 경우의 수는 모두 9가지)
# 모델의 성능 평가 기준은 다음의 우선순위에 따라 결정하시오. 
# 1. Validation Loss가 최소, 2. Accuracy는 최고값에 가까울 것
# 9번의 실험 후 최적이라고 생각되는 파라미터 값을 코드에 지정하고 셀을 다시 run하여 최종 결과를 출력하시오.
from sklearn.datasets import make_blobs
from keras.layers import Dense
from keras.models import Sequential
from keras.optimizers import SGD
from keras.utils.np_utils import to_categorical
from matplotlib import pyplot

# prepare train and test dataset
def prepare_data():
	# generate 2d classification dataset
	X, y = make_blobs(n_samples=1000, centers=3, n_features=2, cluster_std=2, random_state=2)
	# one hot encode output variable
	y = to_categorical(y)
	# split into train and test
	n_train = 500
	trainX, testX = X[:n_train, :], X[n_train:, :]
	trainy, testy = y[:n_train], y[n_train:]
	return trainX, trainy, testX, testy

# fit a model and plot learning curve
def fit_model(trainX, trainy, testX, testy, n_batch):
	
  # define model
	model = Sequential()
	model.add(Dense(50, input_dim=2, activation='relu', kernel_initializer='he_uniform'))
	model.add(Dense(3, activation='softmax'))
	
  # lr의 값을  0.1, 0.01, 0.001 중에서 선택하여 이곳에 지정
	opt = SGD(lr=0.01, momentum=0.9) 
	model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
	# fit model
	history = model.fit(trainX, trainy, validation_data=(testX, testy), epochs=150, verbose=2, batch_size=n_batch)
	print('accuracy = ', format(history.history['accuracy'][149],".3f"), ' ', 'validation loss = ', format(history.history['val_loss'][149],".3f"))
  # plot learning curves
	pyplot.plot(history.history['accuracy'], label='train')
	pyplot.plot(history.history['val_loss'], label='test')
	pyplot.title('batch='+str(n_batch), pad=-40)



# prepare dataset
trainX, trainy, testX, testy = prepare_data()

# batch_size의 값을   16, 32, 64 중에서 선택하여 이곳에 지정
batch_size = 64

fit_model(trainX, trainy, testX, testy, batch_size)
# show learning curves
pyplot.show()

# 결과를 메모장에 적어놓고 lr과 batch_size를 바꿔가며 최적의 파라미터를 찾아가시오.
# 최적의 lr과 batch_size를 선택하여 위의 코드에 적고 Run한 결과룰 출력하여 제출하시오.
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Epoch 1/150
# 8/8 - 1s - loss: 3.8247 - accuracy: 0.3760 - val_loss: 1.9813 - val_accuracy: 0.5740
# Epoch 2/150
# 8/8 - 0s - loss: 2.1271 - accuracy: 0.5420 - val_loss: 1.7638 - val_accuracy: 0.6320
# Epoch 3/150
# 8/8 - 0s - loss: 1.5061 - accuracy: 0.6040 - val_loss: 1.1867 - val_accuracy: 0.6680
# Epoch 4/150
# 8/8 - 0s - loss: 1.5094 - accuracy: 0.6040 - val_loss: 1.1255 - val_accuracy: 0.6760
# Epoch 5/150
# 8/8 - 0s - loss: 1.2290 - accuracy: 0.6200 - val_loss: 0.9157 - val_accuracy: 0.6580
# Epoch 6/150
# 8/8 - 0s - loss: 0.8405 - accuracy: 0.6780 - val_loss: 0.6441 - val_accuracy: 0.7360
# Epoch 7/150
# 8/8 - 0s - loss: 0.9185 - accuracy: 0.6540 - val_loss: 0.8360 - val_accuracy: 0.7040
# Epoch 8/150
# 8/8 - 0s - loss: 0.9467 - accuracy: 0.6360 - val_loss: 0.7934 - val_accuracy: 0.6980
# Epoch 9/150
# 8/8 - 0s - loss: 0.8930 - accuracy: 0.6640 - val_loss: 0.6561 - val_accuracy: 0.7420
# Epoch 10/150
# 8/8 - 0s - loss: 0.9461 - accuracy: 0.6520 - val_loss: 0.5759 - val_accuracy: 0.7760
# Epoch 11/150
# 8/8 - 0s - loss: 0.7653 - accuracy: 0.6660 - val_loss: 0.7722 - val_accuracy: 0.6380
# Epoch 12/150
# 8/8 - 0s - loss: 0.6999 - accuracy: 0.6940 - val_loss: 0.6121 - val_accuracy: 0.7600
# Epoch 13/150
# 8/8 - 0s - loss: 0.5983 - accuracy: 0.7160 - val_loss: 0.5057 - val_accuracy: 0.8200
# Epoch 14/150
# 8/8 - 0s - loss: 0.5530 - accuracy: 0.7460 - val_loss: 0.5096 - val_accuracy: 0.7860
# Epoch 15/150
# 8/8 - 0s - loss: 0.5296 - accuracy: 0.7740 - val_loss: 0.5047 - val_accuracy: 0.8180
# Epoch 16/150
# 8/8 - 0s - loss: 0.5414 - accuracy: 0.7720 - val_loss: 0.4968 - val_accuracy: 0.7840
# Epoch 17/150
# 8/8 - 0s - loss: 0.5401 - accuracy: 0.7540 - val_loss: 0.4933 - val_accuracy: 0.8160
# Epoch 18/150
# 8/8 - 0s - loss: 0.4988 - accuracy: 0.7820 - val_loss: 0.5186 - val_accuracy: 0.8000
# Epoch 19/150
# 8/8 - 0s - loss: 0.4987 - accuracy: 0.7880 - val_loss: 0.4737 - val_accuracy: 0.8160
# Epoch 20/150
# 8/8 - 0s - loss: 0.4908 - accuracy: 0.7780 - val_loss: 0.4564 - val_accuracy: 0.8240
# Epoch 21/150
# 8/8 - 0s - loss: 0.4783 - accuracy: 0.7860 - val_loss: 0.5110 - val_accuracy: 0.7840
# Epoch 22/150
# 8/8 - 0s - loss: 0.5443 - accuracy: 0.7760 - val_loss: 0.5277 - val_accuracy: 0.7740
# Epoch 23/150
# 8/8 - 0s - loss: 0.5195 - accuracy: 0.7780 - val_loss: 0.4465 - val_accuracy: 0.8260
# Epoch 24/150
# 8/8 - 0s - loss: 0.5016 - accuracy: 0.7740 - val_loss: 0.5040 - val_accuracy: 0.8040
# Epoch 25/150
# 8/8 - 0s - loss: 0.5158 - accuracy: 0.7820 - val_loss: 0.6085 - val_accuracy: 0.7260
# Epoch 26/150
# 8/8 - 0s - loss: 0.5162 - accuracy: 0.7760 - val_loss: 0.5384 - val_accuracy: 0.7700
# Epoch 27/150
# 8/8 - 0s - loss: 0.4983 - accuracy: 0.7840 - val_loss: 0.4650 - val_accuracy: 0.8180
# Epoch 28/150
# 8/8 - 0s - loss: 0.4869 - accuracy: 0.7960 - val_loss: 0.4279 - val_accuracy: 0.8280
# Epoch 29/150
# 8/8 - 0s - loss: 0.4783 - accuracy: 0.7920 - val_loss: 0.4373 - val_accuracy: 0.8160
# Epoch 30/150
# 8/8 - 0s - loss: 0.4526 - accuracy: 0.8080 - val_loss: 0.4406 - val_accuracy: 0.8180
# Epoch 31/150
# 8/8 - 0s - loss: 0.4905 - accuracy: 0.7680 - val_loss: 0.4843 - val_accuracy: 0.7980
# Epoch 32/150
# 8/8 - 0s - loss: 0.4487 - accuracy: 0.8080 - val_loss: 0.4289 - val_accuracy: 0.8320
# Epoch 33/150
# 8/8 - 0s - loss: 0.4510 - accuracy: 0.8040 - val_loss: 0.4360 - val_accuracy: 0.8260
# Epoch 34/150
# 8/8 - 0s - loss: 0.4469 - accuracy: 0.8060 - val_loss: 0.4211 - val_accuracy: 0.8320
# Epoch 35/150
# 8/8 - 0s - loss: 0.4594 - accuracy: 0.8000 - val_loss: 0.4478 - val_accuracy: 0.8240
# Epoch 36/150
# 8/8 - 0s - loss: 0.4677 - accuracy: 0.7940 - val_loss: 0.4235 - val_accuracy: 0.8360
# Epoch 37/150
# 8/8 - 0s - loss: 0.4463 - accuracy: 0.8060 - val_loss: 0.4195 - val_accuracy: 0.8300
# Epoch 38/150
# 8/8 - 0s - loss: 0.4674 - accuracy: 0.8080 - val_loss: 0.4244 - val_accuracy: 0.8180
# Epoch 39/150
# 8/8 - 0s - loss: 0.4520 - accuracy: 0.7900 - val_loss: 0.4273 - val_accuracy: 0.8140
# Epoch 40/150
# 8/8 - 0s - loss: 0.4361 - accuracy: 0.8220 - val_loss: 0.4571 - val_accuracy: 0.8040
# Epoch 41/150
# 8/8 - 0s - loss: 0.5039 - accuracy: 0.7760 - val_loss: 0.4458 - val_accuracy: 0.8200
# Epoch 42/150
# 8/8 - 0s - loss: 0.4817 - accuracy: 0.8080 - val_loss: 0.4118 - val_accuracy: 0.8300
# Epoch 43/150
# 8/8 - 0s - loss: 0.4358 - accuracy: 0.8220 - val_loss: 0.4122 - val_accuracy: 0.8340
# Epoch 44/150
# 8/8 - 0s - loss: 0.4241 - accuracy: 0.8240 - val_loss: 0.4069 - val_accuracy: 0.8380
# Epoch 45/150
# 8/8 - 0s - loss: 0.4225 - accuracy: 0.8160 - val_loss: 0.4166 - val_accuracy: 0.8300
# Epoch 46/150
# 8/8 - 0s - loss: 0.4379 - accuracy: 0.8120 - val_loss: 0.4181 - val_accuracy: 0.8280
# Epoch 47/150
# 8/8 - 0s - loss: 0.4843 - accuracy: 0.7940 - val_loss: 0.4335 - val_accuracy: 0.8300
# Epoch 48/150
# 8/8 - 0s - loss: 0.4976 - accuracy: 0.7940 - val_loss: 0.5226 - val_accuracy: 0.7760
# Epoch 49/150
# 8/8 - 0s - loss: 0.5110 - accuracy: 0.7760 - val_loss: 0.5750 - val_accuracy: 0.7320
# Epoch 50/150
# 8/8 - 0s - loss: 0.4719 - accuracy: 0.7900 - val_loss: 0.4668 - val_accuracy: 0.8120
# Epoch 51/150
# 8/8 - 0s - loss: 0.4824 - accuracy: 0.8020 - val_loss: 0.4435 - val_accuracy: 0.8200
# Epoch 52/150
# 8/8 - 0s - loss: 0.5044 - accuracy: 0.7940 - val_loss: 0.4132 - val_accuracy: 0.8340
# Epoch 53/150
# 8/8 - 0s - loss: 0.5236 - accuracy: 0.7860 - val_loss: 0.4734 - val_accuracy: 0.8100
# Epoch 54/150
# 8/8 - 0s - loss: 0.4513 - accuracy: 0.8120 - val_loss: 0.4117 - val_accuracy: 0.8260
# Epoch 55/150
# 8/8 - 0s - loss: 0.4290 - accuracy: 0.8200 - val_loss: 0.4169 - val_accuracy: 0.8300
# Epoch 56/150
# 8/8 - 0s - loss: 0.4664 - accuracy: 0.8180 - val_loss: 0.4093 - val_accuracy: 0.8340
# Epoch 57/150
# 8/8 - 0s - loss: 0.4060 - accuracy: 0.8460 - val_loss: 0.4047 - val_accuracy: 0.8300
# Epoch 58/150
# 8/8 - 0s - loss: 0.4265 - accuracy: 0.8240 - val_loss: 0.4236 - val_accuracy: 0.8240
# Epoch 59/150
# 8/8 - 0s - loss: 0.4133 - accuracy: 0.8280 - val_loss: 0.4074 - val_accuracy: 0.8320
# Epoch 60/150
# 8/8 - 0s - loss: 0.4140 - accuracy: 0.8220 - val_loss: 0.4015 - val_accuracy: 0.8280
# Epoch 61/150
# 8/8 - 0s - loss: 0.4111 - accuracy: 0.8360 - val_loss: 0.4197 - val_accuracy: 0.8300
# Epoch 62/150
# 8/8 - 0s - loss: 0.4094 - accuracy: 0.8260 - val_loss: 0.3990 - val_accuracy: 0.8380
# Epoch 63/150
# 8/8 - 0s - loss: 0.4091 - accuracy: 0.8320 - val_loss: 0.4081 - val_accuracy: 0.8300
# Epoch 64/150
# 8/8 - 0s - loss: 0.4155 - accuracy: 0.8120 - val_loss: 0.4288 - val_accuracy: 0.8280
# Epoch 65/150
# 8/8 - 0s - loss: 0.4481 - accuracy: 0.8100 - val_loss: 0.4070 - val_accuracy: 0.8300
# Epoch 66/150
# 8/8 - 0s - loss: 0.4431 - accuracy: 0.8100 - val_loss: 0.3996 - val_accuracy: 0.8300
# Epoch 67/150
# 8/8 - 0s - loss: 0.4224 - accuracy: 0.8280 - val_loss: 0.4002 - val_accuracy: 0.8380
# Epoch 68/150
# 8/8 - 0s - loss: 0.4330 - accuracy: 0.8060 - val_loss: 0.4080 - val_accuracy: 0.8400
# Epoch 69/150
# 8/8 - 0s - loss: 0.4239 - accuracy: 0.8200 - val_loss: 0.4193 - val_accuracy: 0.8280
# Epoch 70/150
# 8/8 - 0s - loss: 0.4110 - accuracy: 0.8260 - val_loss: 0.4382 - val_accuracy: 0.8220
# Epoch 71/150
# 8/8 - 0s - loss: 0.4134 - accuracy: 0.8300 - val_loss: 0.4121 - val_accuracy: 0.8400
# Epoch 72/150
# 8/8 - 0s - loss: 0.4295 - accuracy: 0.8260 - val_loss: 0.4171 - val_accuracy: 0.8260
# Epoch 73/150
# 8/8 - 0s - loss: 0.4551 - accuracy: 0.8120 - val_loss: 0.4745 - val_accuracy: 0.8080
# Epoch 74/150
# 8/8 - 0s - loss: 0.4332 - accuracy: 0.8160 - val_loss: 0.4221 - val_accuracy: 0.8260
# Epoch 75/150
# 8/8 - 0s - loss: 0.4204 - accuracy: 0.8240 - val_loss: 0.4060 - val_accuracy: 0.8300
# Epoch 76/150
# 8/8 - 0s - loss: 0.4833 - accuracy: 0.8060 - val_loss: 0.4400 - val_accuracy: 0.8080
# Epoch 77/150
# 8/8 - 0s - loss: 0.4562 - accuracy: 0.7880 - val_loss: 0.4755 - val_accuracy: 0.8140
# Epoch 78/150
# 8/8 - 0s - loss: 0.5093 - accuracy: 0.8040 - val_loss: 0.4117 - val_accuracy: 0.8200
# Epoch 79/150
# 8/8 - 0s - loss: 0.5345 - accuracy: 0.7860 - val_loss: 0.4641 - val_accuracy: 0.8080
# Epoch 80/150
# 8/8 - 0s - loss: 0.4392 - accuracy: 0.8080 - val_loss: 0.4338 - val_accuracy: 0.8200
# Epoch 81/150
# 8/8 - 0s - loss: 0.4164 - accuracy: 0.8180 - val_loss: 0.4258 - val_accuracy: 0.8220
# Epoch 82/150
# 8/8 - 0s - loss: 0.4160 - accuracy: 0.8320 - val_loss: 0.4084 - val_accuracy: 0.8360
# Epoch 83/150
# 8/8 - 0s - loss: 0.3972 - accuracy: 0.8400 - val_loss: 0.4158 - val_accuracy: 0.8260
# Epoch 84/150
# 8/8 - 0s - loss: 0.4222 - accuracy: 0.8220 - val_loss: 0.4090 - val_accuracy: 0.8300
# Epoch 85/150
# 8/8 - 0s - loss: 0.4146 - accuracy: 0.8360 - val_loss: 0.4061 - val_accuracy: 0.8340
# Epoch 86/150
# 8/8 - 0s - loss: 0.4105 - accuracy: 0.8160 - val_loss: 0.3985 - val_accuracy: 0.8320
# Epoch 87/150
# 8/8 - 0s - loss: 0.4054 - accuracy: 0.8400 - val_loss: 0.3985 - val_accuracy: 0.8280
# Epoch 88/150
# 8/8 - 0s - loss: 0.3988 - accuracy: 0.8300 - val_loss: 0.4079 - val_accuracy: 0.8280
# Epoch 89/150
# 8/8 - 0s - loss: 0.3990 - accuracy: 0.8420 - val_loss: 0.4012 - val_accuracy: 0.8300
# Epoch 90/150
# 8/8 - 0s - loss: 0.4089 - accuracy: 0.8160 - val_loss: 0.4171 - val_accuracy: 0.8260
# Epoch 91/150
# 8/8 - 0s - loss: 0.3978 - accuracy: 0.8340 - val_loss: 0.4006 - val_accuracy: 0.8380
# Epoch 92/150
# 8/8 - 0s - loss: 0.4153 - accuracy: 0.8160 - val_loss: 0.4249 - val_accuracy: 0.8200
# Epoch 93/150
# 8/8 - 0s - loss: 0.4590 - accuracy: 0.8120 - val_loss: 0.4186 - val_accuracy: 0.8340
# Epoch 94/150
# 8/8 - 0s - loss: 0.4103 - accuracy: 0.8140 - val_loss: 0.4179 - val_accuracy: 0.8300
# Epoch 95/150
# 8/8 - 0s - loss: 0.4017 - accuracy: 0.8320 - val_loss: 0.3978 - val_accuracy: 0.8300
# Epoch 96/150
# 8/8 - 0s - loss: 0.4063 - accuracy: 0.8220 - val_loss: 0.4076 - val_accuracy: 0.8380
# Epoch 97/150
# 8/8 - 0s - loss: 0.4015 - accuracy: 0.8240 - val_loss: 0.4241 - val_accuracy: 0.8240
# Epoch 98/150
# 8/8 - 0s - loss: 0.4099 - accuracy: 0.8100 - val_loss: 0.4431 - val_accuracy: 0.8220
# Epoch 99/150
# 8/8 - 0s - loss: 0.4165 - accuracy: 0.8420 - val_loss: 0.4438 - val_accuracy: 0.8100
# Epoch 100/150
# 8/8 - 0s - loss: 0.4057 - accuracy: 0.8260 - val_loss: 0.4377 - val_accuracy: 0.8240
# Epoch 101/150
# 8/8 - 0s - loss: 0.4215 - accuracy: 0.8200 - val_loss: 0.4270 - val_accuracy: 0.8220
# Epoch 102/150
# 8/8 - 0s - loss: 0.4050 - accuracy: 0.8160 - val_loss: 0.4141 - val_accuracy: 0.8220
# Epoch 103/150
# 8/8 - 0s - loss: 0.3992 - accuracy: 0.8240 - val_loss: 0.4264 - val_accuracy: 0.8220
# Epoch 104/150
# 8/8 - 0s - loss: 0.4038 - accuracy: 0.8280 - val_loss: 0.4116 - val_accuracy: 0.8260
# Epoch 105/150
# 8/8 - 0s - loss: 0.4254 - accuracy: 0.8180 - val_loss: 0.4026 - val_accuracy: 0.8260
# Epoch 106/150
# 8/8 - 0s - loss: 0.3992 - accuracy: 0.8300 - val_loss: 0.4018 - val_accuracy: 0.8340
# Epoch 107/150
# 8/8 - 0s - loss: 0.4047 - accuracy: 0.8220 - val_loss: 0.4097 - val_accuracy: 0.8280
# Epoch 108/150
# 8/8 - 0s - loss: 0.4045 - accuracy: 0.8280 - val_loss: 0.4189 - val_accuracy: 0.8200
# Epoch 109/150
# 8/8 - 0s - loss: 0.3944 - accuracy: 0.8300 - val_loss: 0.4038 - val_accuracy: 0.8260
# Epoch 110/150
# 8/8 - 0s - loss: 0.3922 - accuracy: 0.8380 - val_loss: 0.4034 - val_accuracy: 0.8220
# Epoch 111/150
# 8/8 - 0s - loss: 0.3939 - accuracy: 0.8360 - val_loss: 0.4047 - val_accuracy: 0.8240
# Epoch 112/150
# 8/8 - 0s - loss: 0.3935 - accuracy: 0.8340 - val_loss: 0.4243 - val_accuracy: 0.8300
# Epoch 113/150
# 8/8 - 0s - loss: 0.3969 - accuracy: 0.8240 - val_loss: 0.4199 - val_accuracy: 0.8200
# Epoch 114/150
# 8/8 - 0s - loss: 0.3951 - accuracy: 0.8340 - val_loss: 0.4011 - val_accuracy: 0.8280
# Epoch 115/150
# 8/8 - 0s - loss: 0.3972 - accuracy: 0.8300 - val_loss: 0.4129 - val_accuracy: 0.8240
# Epoch 116/150
# 8/8 - 0s - loss: 0.4073 - accuracy: 0.8280 - val_loss: 0.4026 - val_accuracy: 0.8300
# Epoch 117/150
# 8/8 - 0s - loss: 0.3935 - accuracy: 0.8320 - val_loss: 0.4092 - val_accuracy: 0.8260
# Epoch 118/150
# 8/8 - 0s - loss: 0.3969 - accuracy: 0.8260 - val_loss: 0.4158 - val_accuracy: 0.8240
# Epoch 119/150
# 8/8 - 0s - loss: 0.3928 - accuracy: 0.8340 - val_loss: 0.4040 - val_accuracy: 0.8260
# Epoch 120/150
# 8/8 - 0s - loss: 0.3916 - accuracy: 0.8340 - val_loss: 0.4325 - val_accuracy: 0.8200
# Epoch 121/150
# 8/8 - 0s - loss: 0.3970 - accuracy: 0.8300 - val_loss: 0.4055 - val_accuracy: 0.8260
# Epoch 122/150
# 8/8 - 0s - loss: 0.3942 - accuracy: 0.8300 - val_loss: 0.4561 - val_accuracy: 0.8060
# Epoch 123/150
# 8/8 - 0s - loss: 0.4138 - accuracy: 0.8320 - val_loss: 0.4173 - val_accuracy: 0.8300
# Epoch 124/150
# 8/8 - 0s - loss: 0.4200 - accuracy: 0.8060 - val_loss: 0.4011 - val_accuracy: 0.8320
# Epoch 125/150
# 8/8 - 0s - loss: 0.4025 - accuracy: 0.8200 - val_loss: 0.4020 - val_accuracy: 0.8260
# Epoch 126/150
# 8/8 - 0s - loss: 0.4052 - accuracy: 0.8140 - val_loss: 0.4213 - val_accuracy: 0.8280
# Epoch 127/150
# 8/8 - 0s - loss: 0.4092 - accuracy: 0.8220 - val_loss: 0.4371 - val_accuracy: 0.8220
# Epoch 128/150
# 8/8 - 0s - loss: 0.4046 - accuracy: 0.8280 - val_loss: 0.4056 - val_accuracy: 0.8320
# Epoch 129/150
# 8/8 - 0s - loss: 0.4004 - accuracy: 0.8280 - val_loss: 0.4256 - val_accuracy: 0.8320
# Epoch 130/150
# 8/8 - 0s - loss: 0.3961 - accuracy: 0.8220 - val_loss: 0.4104 - val_accuracy: 0.8260
# Epoch 131/150
# 8/8 - 0s - loss: 0.3902 - accuracy: 0.8360 - val_loss: 0.4049 - val_accuracy: 0.8220
# Epoch 132/150
# 8/8 - 0s - loss: 0.3905 - accuracy: 0.8300 - val_loss: 0.4109 - val_accuracy: 0.8200
# Epoch 133/150
# 8/8 - 0s - loss: 0.3904 - accuracy: 0.8280 - val_loss: 0.4035 - val_accuracy: 0.8260
# Epoch 134/150
# 8/8 - 0s - loss: 0.3959 - accuracy: 0.8340 - val_loss: 0.4091 - val_accuracy: 0.8180
# Epoch 135/150
# 8/8 - 0s - loss: 0.3971 - accuracy: 0.8180 - val_loss: 0.4405 - val_accuracy: 0.8280
# Epoch 136/150
# 8/8 - 0s - loss: 0.4439 - accuracy: 0.8120 - val_loss: 0.4253 - val_accuracy: 0.8200
# Epoch 137/150
# 8/8 - 0s - loss: 0.4133 - accuracy: 0.8260 - val_loss: 0.4077 - val_accuracy: 0.8260
# Epoch 138/150
# 8/8 - 0s - loss: 0.4038 - accuracy: 0.8320 - val_loss: 0.4204 - val_accuracy: 0.8320
# Epoch 139/150
# 8/8 - 0s - loss: 0.3883 - accuracy: 0.8380 - val_loss: 0.4034 - val_accuracy: 0.8280
# Epoch 140/150
# 8/8 - 0s - loss: 0.3953 - accuracy: 0.8340 - val_loss: 0.4007 - val_accuracy: 0.8240
# Epoch 141/150
# 8/8 - 0s - loss: 0.3934 - accuracy: 0.8260 - val_loss: 0.4259 - val_accuracy: 0.8180
# Epoch 142/150
# 8/8 - 0s - loss: 0.3983 - accuracy: 0.8220 - val_loss: 0.4185 - val_accuracy: 0.8240
# Epoch 143/150
# 8/8 - 0s - loss: 0.4111 - accuracy: 0.8300 - val_loss: 0.4193 - val_accuracy: 0.8260
# Epoch 144/150
# 8/8 - 0s - loss: 0.4048 - accuracy: 0.8180 - val_loss: 0.4098 - val_accuracy: 0.8220
# Epoch 145/150
# 8/8 - 0s - loss: 0.3928 - accuracy: 0.8240 - val_loss: 0.4220 - val_accuracy: 0.8140
# Epoch 146/150
# 8/8 - 0s - loss: 0.3971 - accuracy: 0.8280 - val_loss: 0.4096 - val_accuracy: 0.8220
# Epoch 147/150
# 8/8 - 0s - loss: 0.3974 - accuracy: 0.8280 - val_loss: 0.4070 - val_accuracy: 0.8300
# Epoch 148/150
# 8/8 - 0s - loss: 0.3993 - accuracy: 0.8340 - val_loss: 0.4059 - val_accuracy: 0.8220
# Epoch 149/150
# 8/8 - 0s - loss: 0.3885 - accuracy: 0.8360 - val_loss: 0.4153 - val_accuracy: 0.8200
# Epoch 150/150
# 8/8 - 0s - loss: 0.3900 - accuracy: 0.8320 - val_loss: 0.4046 - val_accuracy: 0.8220
# accuracy =  0.832   validation loss =  0.405
